# %% [markdown]
# # Fifa World Cup Prediction Model

# %%
# Importing numpy and pandas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_groups = pd.read_csv('World Cup 2018 Dataset.csv')
df_groups
# Out:
#             Team Group  Previous \nappearances  Previous \ntitles  \
# 0         Russia     A                    10.0                0.0
# 1   Saudi Arabia     A                     4.0                0.0
# 2          Egypt     A                     2.0                0.0
# 3        Uruguay     A                    12.0                2.0
# 4        Porugal     B                     6.0                0.0
# 5          Spain     B                    14.0                1.0
# 6        Morocco     B                     4.0                0.0
# 7           IRAN     B                     4.0                0.0
# 8         France     C                    14.0                1.0
# 9      Australia     C                     4.0                0.0
# 10          Peru     C                     4.0                0.0
# 11       Denmark     C                     4.0                0.0
# 12     Argentina     D                    16.0                2.0
# ...

# %%
df_groups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 20 columns):
# Team                                    32 non-null object
# Group                                   32 non-null object
# Previous
# appearances                   32 non-null float64
# Previous
# titles                        32 non-null float64
# Previous
#  finals                        32 non-null float64
# Previous
#  semifinals                    32 non-null float64
# Current
# FIFA rank                      32 non-null float64
# First match
# against                    32 non-null object
# Match index                             32 non-null float64
# history with
# first opponent
#  W-L       20 non-null float64
# history with
#  first opponent
#  goals     20 non-null float64
# Second match
#  against                   32 non-null object
# Match index.1                           32 non-null float64
# history with
#  second opponent
#  W-L      22 non-null float64
# ...

# %%
# Lets check which country has done more goals in group stage
df_groups.describe()
# Out:
#        Previous \nappearances  Previous \ntitles  Previous\n finals  \
# count               32.000000          32.000000          32.000000
# mean                 7.906250           0.500000           0.843750
# std                  5.426098           1.191367           2.017814
# min                  0.000000           0.000000           0.000000
# 25%                  4.000000           0.000000           0.000000
# 50%                  5.500000           0.000000           0.000000
# 75%                 12.000000           0.000000           0.250000
# max                 20.000000           5.000000           8.000000
#
#        Previous\n semifinals  Current \nFIFA rank  Match index  \
# count              32.000000            32.000000    32.000000
# mean                1.781250            24.781250     8.500000
# std                 3.128788            19.536128     4.683533
# min                 0.000000             1.000000     1.000000
# ...

# %%
print(df_groups['Team'])
# Out:
# 0           Russia
# 1     Saudi Arabia
# 2            Egypt
# 3          Uruguay
# 4          Porugal
# 5            Spain
# 6          Morocco
# 7             IRAN
# 8           France
# 9        Australia
# 10            Peru
# 11         Denmark
# 12       Argentina
# 13         Iceland
# 14         Croatia
# 15         Nigeria
# 16          Brazil
# 17     Switzerland
# 18       Costarica
# 19          Serbia
# 20         Germany
# 21          Mexico
# 22          Sweden
# 23           Korea
# 24         Belgium
# 25          Panama
# 26         Tunisia
# 27         England
# 28          Poland
# 29         Senegal
# 30        Columbia
# 31           Japan
# 32             NaN
# Name: Team, dtype: object

# %%
#First, we will delete non qualified teams
df_groups = df_groups[df_groups.Team != 'Saudi Arabia']
df_groups = df_groups[df_groups.Team != 'Egypt']
df_groups = df_groups[df_groups.Team != 'Morocco']
df_groups = df_groups[df_groups.Team != 'Senegal']
df_groups = df_groups[df_groups.Team != 'Poland']
df_groups = df_groups[df_groups.Team != 'Tunisia']
df_groups = df_groups[df_groups.Team != 'Panama']
df_groups = df_groups[df_groups.Team != 'Korea']
df_groups = df_groups[df_groups.Team != 'Germany']
df_groups = df_groups[df_groups.Team != 'Serbia']
df_groups = df_groups[df_groups.Team != 'Costarica']
df_groups = df_groups[df_groups.Team != 'Nigeria']
df_groups = df_groups[df_groups.Team != 'Australia']
df_groups = df_groups[df_groups.Team != 'Iceland']
df_groups = df_groups[df_groups.Team != 'Peru']
df_groups = df_groups[df_groups.Team != 'IRAN']
df_groups = df_groups[df_groups.Team != 'NaN']
df_groups
# Out:
#            Team Group  Previous \nappearances  Previous \ntitles  \
# 0        Russia     A                    10.0                0.0
# 3       Uruguay     A                    12.0                2.0
# 4       Porugal     B                     6.0                0.0
# 5         Spain     B                    14.0                1.0
# 8        France     C                    14.0                1.0
# 11      Denmark     C                     4.0                0.0
# 12    Argentina     D                    16.0                2.0
# 14      Croatia     D                     4.0                0.0
# 16       Brazil     E                    20.0                5.0
# 17  Switzerland     E                    10.0                0.0
# 21       Mexico     F                    15.0                0.0
# 22       Sweden     F                    11.0                0.0
# 24      Belgium     G                    12.0                0.0
# ...

# %%
# Delete the null values in all rows
df_cleaned = df_groups.dropna(how='all')
df_cleaned
# Out:
#            Team Group  Previous \nappearances  Previous \ntitles  \
# 0        Russia     A                    10.0                0.0
# 3       Uruguay     A                    12.0                2.0
# 4       Porugal     B                     6.0                0.0
# 5         Spain     B                    14.0                1.0
# 8        France     C                    14.0                1.0
# 11      Denmark     C                     4.0                0.0
# 12    Argentina     D                    16.0                2.0
# 14      Croatia     D                     4.0                0.0
# 16       Brazil     E                    20.0                5.0
# 17  Switzerland     E                    10.0                0.0
# 21       Mexico     F                    15.0                0.0
# 22       Sweden     F                    11.0                0.0
# 24      Belgium     G                    12.0                0.0
# ...

# %%
# Reset Index
df_cleaned.reset_index()
# Out:
#     index         Team Group  Previous \nappearances  Previous \ntitles  \
# 0       0       Russia     A                    10.0                0.0
# 1       3      Uruguay     A                    12.0                2.0
# 2       4      Porugal     B                     6.0                0.0
# 3       5        Spain     B                    14.0                1.0
# 4       8       France     C                    14.0                1.0
# 5      11      Denmark     C                     4.0                0.0
# 6      12    Argentina     D                    16.0                2.0
# 7      14      Croatia     D                     4.0                0.0
# 8      16       Brazil     E                    20.0                5.0
# 9      17  Switzerland     E                    10.0                0.0
# 10     21       Mexico     F                    15.0                0.0
# 11     22       Sweden     F                    11.0                0.0
# ...

# %% [markdown]
# AFter cleaning table, we have top 16 qualified team in quaterfinals. We will check performance of the team. Quaterfinals are decided. Hence, we will check one is to one ratio with teams.

# %% [markdown]
# # Prediction
# #### Winner - France
# #### Runners up - England
# #### Semifinalist 3 - Belgium
# #### Semifinalist 4 - Spain
